# %%
from huggingface_hub.file_download import hf_hub_download

model_fp = hf_hub_download('microsoft/msclap', 'CLAP_weights_2023.pth')
# Out:
# CLAP_weights_2023.pth:   0%|          | 0.00/690M [00:00<?, ?B/s]

# %%
from clap_model import ClapModel
import torch

device = torch.device('cuda:0')
model = ClapModel('2022', device)
# Out:
# <class 'str'>
# bert-base-uncased
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/pkgutil.py:417, in get_importer(path_item)
#     416 try:
# --> 417     importer = sys.path_importer_cache[path_item]
#     418 except KeyError:
#
# KeyError: PosixPath('/home/royhirsch/audio_embed/models/clap')
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 5
#       2 import torch
#       4 device = torch.device('cuda:0')
# ----> 5 model = ClapModel('2022', device)
#
# File ~/audio_embed/models/clap/clap_model.py:56, in ClapModel.__init__(self, model_name, device)
#      54     self.clapcap, self.tokenizer, self.args = self.load_clapcap()
#      55 else:
# ---> 56     self.clap, self.tokenizer, self.args = self.load_clap()
#
# ...
